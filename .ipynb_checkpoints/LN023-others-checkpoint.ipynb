# %%
from IPython.display import Image
Image("./images/cartoon-why.png",width=200)

# %% [markdown]
# ## [Matplotlib](https://matplotlib.org/gallery/index.html)

# %% [markdown]
# ## [basemap](https://basemaptutorial.readthedocs.io/en/latest/)

# %% [markdown]
# ## [Cartopy](https://scitools.org.uk/cartopy/docs/latest/)

# %% [markdown]
# ## [Mayavi](https://docs.enthought.com/mayavi/mayavi/)

# %% [markdown]
# ## [scikit-image](https://scikit-image.org)

# %% [markdown]
# ## [scikit-learn](https://scikit-learn.org/stable/)

# %% [markdown]
# # Practice and self-study are the keys for learning python

# %% [markdown]
# ## [Introduction to Python for computational science and engineering by Fangohr](http://www.southampton.ac.uk/~fangohr/training/python/pdfs/Python-for-Computational-Science-and-Engineering.pdf)

# %% [markdown]
# ## [Making games with Python and Pygame by Sweigart](https://inventwithpython.com/makinggames.pdf)

# %% [markdown]
# ## [Think Stats by Downey](http://greenteapress.com/thinkstats/)

# %% [markdown]
# ## [23 Free Data Science Books](http://www.wzchen.com/data-science-books/)
