# 2.030928584138856152e+01 -7.522173214573188993e-01
# 2.062661843266025841e+01 -9.458091008575378877e-01
# 2.094395102393195529e+01 -6.514158233798443802e-15
# 2.126128361520364862e+01 8.121102389696881474e-01
# 2.157861620647534551e+01 9.617217165848745974e-01
# 2.189594879774704239e+01 2.812540501629127165e-01
# 2.221328138901873928e+01 -1.001513788026293872e+00
# 2.253061398029043616e+01 -1.997833939188619734e+00
# 2.284794657156213304e+01 -3.950614598171975356e-01
# 2.316527916283382638e+01 4.661239092608633339e-01
# 2.348261175410552326e+01 1.180431586280766165e+00
# 2.379994434537722015e+01 7.718962751532211231e-01
# 2.411727693664891703e+01 -7.537205747558631264e-02
# 2.443460952792061391e+01 -8.584865000123123036e-01
# 2.475194211919231080e+01 -3.647731742349492601e-01
# 2.506927471046400413e+01 -8.968392916111619928e-02
# 2.538660730173570101e+01 5.494518508585531924e-01
# 2.570393989300739790e+01 3.201399248996160130e-01
# 2.602127248427909478e+01 5.773525314436015465e-01
# 2.633860507555079167e+01 -2.882438030856679934e-01
# 2.665593766682248855e+01 2.274012169031450203e-01
# 2.697327025809418188e+01 -4.690198123685384579e-01
# 2.729060284936587877e+01 1.163467819153290034e-01
# 2.760793544063757565e+01 8.978281366567585353e-01
# 2.792526803190927254e+01 4.371677514250929542e-01
# 2.824260062318096942e+01 2.672194758965858175e-02
# 2.855993321445266631e+01 -2.043560081768518166e-02
# 2.887726580572435964e+01 -4.474383154114562888e-01
# 2.919459839699605652e+01 -2.303660319820007851e-01
# 2.951193098826775341e+01 1.039428963221978317e-03
# 2.982926357953945029e+01 8.068664854198719372e-01
# 3.014659617081114718e+01 1.511313922036303936e-01
# 3.046392876208284406e+01 -2.212953048257879085e-01
# 3.078126135335453739e+01 -2.557730835503351785e-01
# 3.109859394462623428e+01 -3.837213991721588058e-01
# 3.141592653589793116e+01 -3.611573940935276362e-15

# %% [markdown]
# # Step 1:
# - read the data
# - plot the data

# %%
#use np.loadtxt() to read the data

# %% [markdown]
# # Step 2:

# %% [markdown]
# - Write a program using the SciPy function scipy.optimize.curve_fit to fit the equation to the data. Do not consider the uncertainty of y-axis this time, and do not give initial values of the constants. Your program should plot the data along with the fitting function using the optimal values of the fitting parameters.
# - Print out fitting residual. The fitting resitual is defined as:
# \begin{align}
# residual=\sqrt{[\sum_{i=1}^n(y^i-y_{fit}^i)^2]/n}
# \end{align}
# where $y^i$ is the observed y-data, and $y_{fit}^i$ is the modeled y-data computed from the fitting function, $n$ is the number of data points

# %% [markdown]
# ## Problem #2

# %% [markdown]
# Fit the following data with the function of
# \begin{align}
# d(t) = A (1+B\,\cos\omega t) e^{-t^2/(2\tau^2)} + C
# \end{align}
#
# Find the constants of A, B, C, tau and omega
#
# - HINT: in this problem, you will need carefully chose initial values for these constants by using the 'p0' option, otherwise, you can not fit the data well. The defult initial values for these constants are 1. You will need use different values than the default to fit the data well.

# %%
# The data is here
# %less ./data/spec.dat
# Out:
# 0.2 41.1
# 1.4 37.2
# 2.7 28.3
# 3.9 24.8
# 5.1 27.8
# 6.4 34.5
# 7.6 39.0
# 8.8 37.7
# 10.1 29.8
# 11.3 22.2
# 12.5 22.3
# 13.8 26.7
# 15.0 30.4
# 16.2 32.6
# 17.5 28.9
# 18.7 22.9
# 19.9 21.7
# 21.1 22.1
# 22.4 22.3
# 23.6 26.3
# 24.8 26.2
# 26.1 21.4
# 27.3 20.0
# 28.5 20.1
# 29.8 21.2
# 31.0 22.0
# 32.2 21.6
# 33.5 21.0
# 34.7 19.7
# 35.9 17.9
# 37.2 18.1
# 38.4 18.9
