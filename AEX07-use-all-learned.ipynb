# %% [markdown]
# # Exercise 07

# %% [markdown]
# * In this exercies, we will use what we have learned about Python to process real data in our real life.
# * The data is "./data/earthquake.csv"
# * This data is download from https://www.iris.edu/hq/, and is an earthquake catalogue in the last month.
# * The data contain not only numbers, but strings. In addition, the strings have different format, which makes the problem a bit more complex. It is the true life.
# * Let's work on it together as a group.

# %%
import numpy as np
fp=open("./data/earthquake.csv","r")
lines=fp.readlines()
fp.close()
year=[];month=[];day=[];time=[];mag=[];lon=[];lat=[];depth=[];region=[]
for line in lines[1:]:
    if "\"" in line:
        temp=line.split(",")
        year.append(temp[0]);month.append(temp[1])
        day.append(temp[2]);time.append(temp[3])
        mag.append(temp[4]);lon.append(temp[5]);lat.append(temp[6])
        depth.append(temp[7]);region.append(temp[8]+","+temp[9])
    else:
        temp=line.split(",")
        year.append(temp[0]);month.append(temp[1])
        day.append(temp[2]);time.append(temp[3])
        mag.append(temp[4]);lon.append(temp[5]);lat.append(temp[6])
        depth.append(temp[7]);region.append(temp[8])

# %%
np.array(mag)
# Out:
# array(['2', '1.1', '1.9', '1.5', '2.7', '4.2', '2.5', '2', '2.7', '1.1',
#        '1.7', '2.3', '0.8', '1.2', '5.3', '1.7', '4.2', '2.5', '0.9', '2',
#        '2.8', '1.5', '2.1', '1.6', '1.1', '4.6', '4.7', '3.1', '2.1', '3',
#        '1.8', '0.9', '2.5', '2.8', '2.1', '1.5', '1.8', '0.7', '1.4',
#        '4.3', '1', '1.8', '2.2', '1.5', '0.8', '1.6', '1.4', '0.5', '1.4',
#        '1.3', '0.2', '1.8', '2', '2.7', '2.1', '1.2', '2', '1.9', '4.5',
#        '2.7', '0.6', '1.2', '1.1', '1.4', '1', '4.5', '3.6', '3', '0.4',
#        '1.8', '3.3', '4.6', '1.8', '1.6', '3.3', '4.4', '1.5', '1.3',
#        '1.1', '3.3', '0.9', '0.6', '3.4', '1.5', '2.6', '0.4', '4', '5.2',
#        '2.5', '4.6', '3.2', '4.6', '0.4', '2.8', '0.9', '2.3', '0.8',
#        '4.8', '0.6', '3.6', '5.1', '0.9', '4.4', '1.3', '1.9', '1.3',
#        '1.5', '1', '3', '1.7', '1.7', '3.5', '2.5', '3.3', '2.2', '1.5',
#        '0.8', '1.8', '2.2', '1.2', '5.3', '0.9', '0.6', '1.4', '2.7',
#        '1.7', '2.1', '1.8', '0.9', '2', '2', '1.2', '0.6', '1.2', '2.8',
#        '0.8', '2', '2.1', '1.7', '2', '1.8', '4.3', '1.2', '1.3', '1.6',
#        '1.4', '1.1', '1.4', '1.6', '1.3', '1.9', '2', '2.3', '1.1', '1.8',
#        '1.1', '1.3', '0.8', '4.6', '1.3', '2', '1.6', '5.1', '1.6', '1.5',
#        '1.6', '2.1', '0.9', '2.1', '2.8', '1.6', '2.3', '4.5', '1', '1.5',
#        '1.8', '0.7', '5.2', '0.6', '0.7', '0.8', '4.7', '1', '0.4', '1.8',
#        '0.8', '1.8', '0.9', '1.3', '1.4', '1.3', '1.6', '2.9', '1.2',
#        '5.2', '2.1', '4.5', '0.8', '2.4', '5', '2.3', '4.6', '1.1', '1.5',
#        '1.4', '2.5', '1.8', '1.5', '1.7', '1.5', '0.8', '2.9', '1.8',
#        '1.7', '4.2', '1.3', '0.6', '1.4', '1.1', '1.1', '1.4', '0.8',
#        '4.8', '1.3', '3', '1.4', '2.1', '5.2', '1.8', '0.8', '1.7', '1.2',
#        '2.2', '1.4', '4.8', '1.8', '1.9', '1.3', '0.9', '0.8', '1.5',
#        '0.7', '1.9', '1.5', '1.1', '1.2', '2.9', '4.4', '1.8', '3.5',
#        '1.5', '1.7', '1.9', '0.9', '1.9', '5.1', '1.1', '1.6', '0.8',
#        '1.2', '1.9', '1.1', '1.5', '1.9', '3.2', '0.4', '2.9', '1.9',
#        '1.4', '1.4', '1.3', '1.3', '2.2', '0.9', '1.6', '2.3', '1.7', '1',
#        '0.8', '1.7', '0.9', '2.3', '2.3', '1.3', '4.9', '1.4', '1.6',
#        '1.3', '0.9', '3.4', '3.6', '0.8', '1.1', '0.6', '1.3', '1.8',
#        '1.8', '1.1', '1.2', '1.3', '1.4', '1.4', '1.3', '1.3', '2.3',
#        '1.3', '2.6', '2.1', '2.1', '2', '1', '2.3', '2.5', '1.2', '1.6',
#        '4.7', '0.9', '1.2', '1.1', '4', '1.2', '2.5', '1.6', '1.4', '1',
#        '0.5', '2', '1.3', '4.1', '0.8', '1.7', '1.4', '0.4', '0.7', '1.8',
#        '1.9', '0.9', '4.7', '1.8', '1.4', '2', '0.7', '1', '0.4', '1.6',
#        '1.8', '1.3', '2.9', '1', '0.6', '0.6', '1.5', '4.7', '1.1', '2.3',
#        '1.6', '1.6', '0.9', '1.2', '0.8', '2', '0.9', '1.7', '1.4', '1.8',
#        '1.4', '2.1', '0.9', '3.6', '1.1', '3', '0.2', '1.4', '0.8', '1.4',
#        '1.4', '4.4', '1.5', '0.8', '0.6', '1.9', '0.4', '4.4', '0.8', '5',
#        '2.6', '1.5', '1.1', '0.6', '0.9', '1.5', '0.7', '2.3', '1.2',
#        '2.1', '1.1', '1', '0.3', '1.4', '1.9', '1.1', '1.2', '1.8', '0.7',
#        '1', '1.9', '1.6', '0.1', '0.8', '1.4', '1.3', '0.8', '1.4', '2.4',
#        '1.8', '1.8', '2', '1.7', '1.6', '1.9', '1.1', '0.4', '2.5', '1.1',
#        '0.8', '2.1', '0.6', '1.8', '0.4', '2.8', '1.5', '2.5', '1.3',
#        '1.4', '1.5', '2.3', '2.9', '1.7', '1.5', '1.6', '1.2', '1.6',
#        '1.7', '1', '4.6', '0.8', '5', '2.1', '0.8', '1.3', '1.3', '1.4',
#        '2.5', '2.3', '4.8', '0.9', '2.5', '0.7', '1.5', '1.1', '4.6',
#        '1.7', '1.1', '1.6', '0.2', '1.3', '1.9', '1.4', '1.7', '1.9',
#        '1.4', '1.5', '1.1', '1', '1.8', '4.7', '2', '0.9', '3', '1.5',
#        '1.1', '2.2', '1.6', '1.5', '1.1', '1.5', '0.4', '1.3', '1.1',
#        '0.4', '1.4', '1.3', '0.6', '4.6', '0.7', '1.6', '4.9', '0.7',
#        '4.7', '1.9', '0.6', '2.1', '1.1', '1.7', '1.6', '1.6', '1.7',
#        '1.2', '1.7', '5', '2.2', '1', '0.2', '1.5', '1.6', '4.7', '1.1',
#        '1.5', '1.9', '2.2', '1.2', '1.2', '3.5', '1.1', '0.9', '1.7',
#        '2.2', '1.6', '2.1', '2.3', '0.7', '1.4', '1.4', '1', '0.8', '0.3',
#        '1.5', '1.4', '0.8', '1.6', '1.9', '1.1', '1.7', '1.1', '0.4',
#        '1.8', '1', '5.1', '1', '2.4', '1.2', '4.7', '5', '0.8', '0.9',
#        '1.5', '0.6', '1', '0.3', '3.3', '0.2', '1.4', '5.9', '0.8', '1.9',
#        '0.3', '0.5', '0.5', '1.2', '2.3', '0.1', '2.9', '0.4', '1.3', '1',
#        '1.8', '4.5', '3.4', '1', '1.6', '0.9', '0.5', '0.6', '2.8', '0.1',
#        '0.1', '2.9', '0.8', '0.2', '1.1', '3.7', '1', '0.3', '2.1', '2.2',
#        '1.7', '2', '2.3', '3.5', '3', '3.1', '1.6', '1.8', '0.5', '0.5',
#        '1.6', '2.8', '1.2', '1', '2.2', '0.8', '1.5', '1.5', '2.4', '1.2',
#        '1', '1.4', '2.5', '0.2', '0.8', '0.5', '0.4', '1.8', '1.6', '0.8',
#        '1.5', '1.7', '2.2', '1.7', '2.8', '1.3', '1.1', '2.6', '2.1',
#        '1.3', '0.3', '2.5', '0.4', '0.6', '0.9', '2.1', '0.9', '1.8',
#        '1.6', '1.4', '2', '1.7', '2.5', '2', '1.4', '1.7', '2.6', '1.4',
#        '2', '1.2', '0.7', '1.7', '5.4', '0.7', '1.4', '1.7', '1.5', '1.5',
#        '0.2', '2.5', '1.6', '2.7', '2.6', '1.5', '2.6', '1.9', '1.8',
#        '2.9', '1.9', '1.5', '2.7', '1', '0.4', '1.5', '2.3', '1.7', '0.6',
#        '1.5', '0.7', '2.5', '0.5', '2.6', '1.8', '1.7', '4.1', '1.6',
#        '1.6', '2.5', '3.5', '2.4', '1.9', '1.7', '1.9', '2.3', '1.7',
#        '1.9', '2.1', '1.7', '1.1', '2.2', '1.1', '1', '0.9', '1.4', '1.7',
#        '1.4', '4.3', '0.9', '0.6', '1.3', '1', '1.7', '4.9', '2', '1.3',
#        '4.3', '0.6', '1', '1', '0.6', '0.4', '1.5', '1.8', '1.1', '1.1',
#        '0.8', '1.1', '1.3', '0.4', '1.2', '1.2', '1.6', '2.9', '3.1',
#        '1.9', '1.3', '1.6', '2.2', '0.8', '1.8', '0.9', '1.7', '1.1',
#        '1.9', '2.1', '1.7', '1', '1.9', '2.9', '0.5', '2', '2', '1.9',
#        '1.3', '4.6', '1.5', '1.6', '2.1', '1.6', '1.5', '4.3', '1', '1.6',
#        '1.1', '1.7', '1.6', '1.1', '1.3', '0.5', '2', '1.7', '1.4', '1.9',
#        '1.1', '1.5', '1.2', '4.6', '1.8', '1.6', '4.2', '0.3', '1.6',
#        '1.5', '2', '1.7', '1', '2.1', '1.7', '2.9', '1.4', '1.7', '1.1',
#        '1.7', '1.2', '1.6', '2', '2.4', '4.6', '2.2', '2', '0.2', '2.7',
#        '1.9', '1.7', '4', '1.5', '1', '2.2', '0.9', '2.2', '2.2', '1.8',
#        '3.5', '0.2', '2.4', '0.1', '3.5', '1.2', '1.6', '1.7', '2.7',
#        '1.4', '0.2', '1.4', '1.6', '1.4', '0.1', '1.5', '0.7', '1.3',
#        '0.5', '2.6', '0.6', '1.9', '1.6', '0.9', '1.4', '2.7', '0.9',
#        '0.4', '0.6', '0.3', '1.4', '1.7', '0.8', '1.6', '1.8', '4.3',
#        '1.9', '2', '1', '0.6', '0.2', '0.8', '1.1', '0.5', '0.3', '2',
#        '3.8', '1.1', '1.3', '0.5', '1.3', '1.8', '1.7', '0.4', '0.6',
#        '0.9', '1', '0.3', '0.8', '2.2', '1', '1.4', '1.2', '1.2', '0.5',
#        '1', '1.1', '1', '1.4', '1.5', '1.6', '0.4', '4.8', '2.1', '5.4',
#        '2.5', '2.3', '2.9', '1.4', '4.8', '1.4', '1.5', '1.7', '0.9',
#        '1.3', '3.3', '1', '2.8', '3.7', '2.5', '4.3', '1.4', '1.4', '1.6',
#        '1.8', '1.3', '1.4', '0.7', '2', '1.4', '3.2', '1.3', '1.2', '1',
#        '1.9', '2.3', '0.7', '4.9', '1', '1.6', '2.8', '2', '1.5', '0.2',
#        '2.9', '1.3', '0.7', '2.6', '1.4', '1.8', '1.7', '2.1', '1.1',
#        '0.8', '1.4', '0.8', '0.7', '1.7', '0.4', '2', '1.4', '4.2', '3',
#        '1.4', '1.8', '1.9', '1', '1', '1.8', '1.3', '1', '1.3', '1.6',
#        '1.1', '1.9', '1.1', '2.4', '5.7', '3.2', '1.7', '2.6', '1.9',
#        '0.7', '1.2', '3.4', '1.1', '1.4', '2.9', '1.7', '3.2', '1.9',
#        '1.8', '1.6', '0.8', '0.5', '2.7', '2', '1.4', '1.8', '1.7', '1.3',
#        '1.6', '2.1', '1.6', '1.6', '5.5', '1.6', '2.9', '0.9', '1.3',
#        '2.2', '2', '1.4'], dtype='<U3')
