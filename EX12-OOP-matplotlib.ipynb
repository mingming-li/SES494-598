# %% [markdown]
# # Exercise 12 OOP matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## make a plot the same as below

# %%
from IPython.display import Image
Image("./figs/sincos.png")
